# %%
import librosa as lr
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
import logging

from torch.utils.data import Dataset, DataLoader
from matplotlib import pyplot  


class VoiceSamples(Dataset):
    
    def __init__(self, core_name, samples_path=None, Automatic=None):
        
        self.Log = logging.getLogger()
        logging.basicConfig(level=logging.INFO)
        
        self.noiseThreshold = 1
        
        self.core_name = core_name
        self.samples_path = samples_path
        
        self.soundSamples = []
        self.sampleRate = []
        self.path = []
        
        self.chopedSamples = []
        self.chopedSr = []
        
        self.tensorMelgrams = []
        
        
        self.info = " VoiceSamples Object successfully created "
        self.Log.info(self.info)
        
        
        if Automatic:
            self.LoadSoundSamples()
            self.ChopToOneSecFragments()
            self.ChopedSignalsToTenosor()
        
    def __len__(self):
        return len(self.tensorMelgrams)
    
    def __getitem__(self, idx):
        if self.tensorMelgrams:
            return self.tensorMelgrams[idx]

    def LoadSoundSamples(self):
    
        n = 1

        while(True):
            try:
                if  self.samples_path:
                    path =  self.samples_path + self.core_name + str(n)
                else:
                    path = self.core_name + str(n)

                soundSample, sampleRate = lr.load(path)

                n += 1
                self.soundSamples.append(soundSample)
                self.sampleRate.append(sampleRate) 
                self.path.append(path)

                self.info = " Sample : " + path + " : successfully added"
                self.Log.info(self.info)

            except FileNotFoundError:
                if self.soundSamples:
                    self.info = "That's the end of database : " + str(n-1) + " : Samples added"
                    self.Log.info(self.info)
                    n = 0
                    
                    return self.soundSamples, self.sampleRate, self.path

                else:
                    self.Log.exception("Files are missing")
                    n = 0

                break

            except Exception as ex:      
                self.Log.exception("Unexpected error")
                break
        
    def getSoundSample(self, idx):
        return self.soundSamples[idx], self.sampleRate[idx]
    
    def getSoundSampleLen(self):
        try:
            if len(self.soundSamples) == len(self.sampleRate):
                return len(self.soundSamples)
            else:
                self.Log.warning("Lists: sundSamples and sampleRate are not equal!")
                
        except Exception as e:
            self.Log.exception("Unexpected error" + e)
    
    def ChopToOneSecFragments(self):
        
        # TODO: make shure user goes step by step 
        
        try:
            if len(self.soundSamples) == len(self.sampleRate):
                for idx in range(len(self.soundSamples)):
                    
                    soundSample = self.soundSamples[idx]
                    sr = self.sampleRate[idx]
                    
                    frag_max = math.trunc(len(soundSample)/float(sr))
                    step = math.trunc(sr/2);
                    last_sample = len(soundSample)

                    for frag in range(frag_max*2):
                        start = step * frag
                        stop = start + sr
                        if sr<len(soundSample):
                            if self.checkIfNotNoise(soundSample[start:stop]):
                                self.chopedSamples.append(soundSample[start:stop])
                                self.chopedSr.append(sr)
                                self.info = self.path[idx] + " : " + str(frag+1) + " : successfully choped"
                                self.Log.info(self.info)
                            else:
                                self.info = self.path[idx] + " : " + str(frag+1) + " : NOISE!"
                                self.Log.info(self.info)
                        else:
                            self.Log.warning("Something went wrong")
                            
                    if self.checkIfNotNoise(soundSample[last_sample-sr:last_sample]):
                         # incuding samples cuted by math.trunc() 
                        self.chopedSamples.append(soundSample[last_sample-sr:last_sample])
                        self.chopedSr.append(sr)
                        self.info = self.path[idx] +  " : "  + str(frag_max*2+1) + " : successfully choped"
                        self.Log.info(self.info)
                    else:
                        self.info = self.path[idx] + " : "  + str(frag+1) + " : NOISE!"
                        self.Log.info(self.info)
                
                if self.chopedSamples:
                    self.Log.info("Sucessfully choped all loaded signals and eliminated the noise!")
                    return self.chopedSamples, self.chopedSr 
                    
            else:
                self.Log.warning("Lists: sundSamples and sampleRate are not equal!")
                
        except Exception as e:
            self.e = "Unexpected error : " + str(e)
            self.Log.exception(self.e)
            
    def getChoped(self, idx):
        return self.chopedSamples[idx], self.chopedSr[idx]
        
    def getChopedLen(self):
        try:
            if len(self.chopedSamples) == len(self.chopedSr):
                    return len(self.chopedSamples)
            else:
                self.Log.warning("Lists: sundSamples and sampleRate are not equal!")
                
        except Exception as e:
            self.Log.exception("Unexpected error" + e)
            
        
    def ChopedSignalsToTenosor(self):
        
        # TODO: make shure user goes step by step 
        
        try:
        
            if len(self.chopedSamples) == len(self.chopedSr):
                for idx in range(len(self.chopedSamples)):

                    # hop length adjusted
                    STFT_signal = np.abs(lr.stft(self.chopedSamples[idx], n_fft = 512, hop_length = round(self.chopedSr[idx]/256))) 
                    STFT_signal = lr.power_to_db(STFT_signal**2,ref=np.max)

                    Melgram = STFT_signal[0:256,0:256]
                    TMelgram = torch.tensor(Melgram)
                    self.tensorMelgrams.append(TMelgram)
                    
                    self.info = " " + self.samples_path +  " : ChopedSample " + str(idx) + " : " + " : converted to tensor"
                    self.Log.info(self.info)
                
                if self.tensorMelgrams:
                    self.Log.info("Sucessfully converted all ChopedSamples to Tensors!")
                    return self.tensorMelgrams
                
            else:
                self.Log.warning("Lists: chopedSamples and chopedSr are not equal!")
                
        except Exception as e:
            self.e = "Unexpected error : " + str(e)
            self.Log.exception(self.e)
                
    
    
    def checkIfNotNoise(self, chopedSample):
    
        chopedSamplePow2 = []

        for n in range(len(chopedSample)):
            chopedSamplePow2.append(chopedSample[n]**2)
        sk = sum(chopedSamplePow2)
        if sk > self.noiseThreshold:
            return True 
        else:
            return False

# %%
# Use torch.save(tensor, 'file.pt') and torch.load('file.pt')

class VoiceSamplesInput():
    def __init__(self):
        
        self.vsKrystian = VoiceSamples("vsKrystian", samples_path="database/Krystian/" , Automatic=True)
        self.vsNicia = VoiceSamples("vsNicia", samples_path="database/Nicia/" , Automatic=True)

        self.targetKrystian = torch.tensor([[float(1),float(0)]])
        self.targetNicia = torch.tensor([[float(0),float(1)]])
        
        
    def __getitem__(self, idx):
        if idx % 2 == 0:
            return self.vsKrystian[int(idx/2)] ,  self.targetKrystian
        else:
            return self.vsNicia[int((idx+1)/2)] , self.targetNicia
    
    def __len__(self):
        if len(self.vsKrystian) <= len(self.vsNicia):
            return len(self.vsKrystian) * 2
        else:
            return len(self.vsNicia) * 2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class VoiceRecogModel(nn.Module):

    def __init__(self):
        super(VoiceRecogModel, self).__init__()
        # 1 input image channel, 6 output channels, 3x3 square convolution
        # kernel
        self.conv1 = nn.Conv2d(1, 6, 3)
        self.conv2 = nn.Conv2d(6, 16, 3)
        # an affine operation: y = Wx + b
        self.fc1 = nn.Linear(16*62*62, 1000)  # ?? from image dimension
        self.fc2 = nn.Linear(1000, 84)
        self.fc3 = nn.Linear(84, 2)

    def forward(self, x):
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        # If the size is a square you can only specify a single number
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = x.view(-1, self.num_flat_features(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

# %%
import torch.optim as optim

# create dataset : loading and processing samples to tensors
vsInput = VoiceSamplesInput()
# Out:
# INFO:root: VoiceSamples Object successfully created
# INFO:root: Sample : database/Krystian/vsKrystian1 : successfully added
# INFO:root: Sample : database/Krystian/vsKrystian2 : successfully added
# INFO:root: Sample : database/Krystian/vsKrystian3 : successfully added
# INFO:root: Sample : database/Krystian/vsKrystian4 : successfully added
# INFO:root: Sample : database/Krystian/vsKrystian5 : successfully added
# INFO:root: Sample : database/Krystian/vsKrystian6 : successfully added
# INFO:root: Sample : database/Krystian/vsKrystian7 : successfully added
# INFO:root: Sample : database/Krystian/vsKrystian8 : successfully added
# INFO:root: Sample : database/Krystian/vsKrystian9 : successfully added
# INFO:root: Sample : database/Krystian/vsKrystian10 : successfully added
# INFO:root: Sample : database/Krystian/vsKrystian11 : successfully added
# INFO:root:That's the end of database : 11 : Samples added
# INFO:root:database/Krystian/vsKrystian1 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian1 : 15 : NOISE!
# INFO:root:database/Krystian/vsKrystian1 : 16 : NOISE!
# INFO:root:database/Krystian/vsKrystian1 : 17 : NOISE!
# INFO:root:database/Krystian/vsKrystian1 : 18 : NOISE!
# INFO:root:database/Krystian/vsKrystian1 : 18 : NOISE!
# INFO:root:database/Krystian/vsKrystian2 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 15 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 16 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 17 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 18 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 19 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 20 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 21 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 22 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 23 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 24 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 25 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 26 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 27 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 28 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 29 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 30 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 31 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 32 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 33 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 34 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 35 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 36 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 37 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 38 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 39 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 40 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 41 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 42 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 43 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 44 : NOISE!
# INFO:root:database/Krystian/vsKrystian2 : 45 : NOISE!
# INFO:root:database/Krystian/vsKrystian2 : 46 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 47 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 48 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 49 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 50 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 51 : NOISE!
# INFO:root:database/Krystian/vsKrystian2 : 52 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 53 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 54 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 55 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 56 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 57 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 58 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 59 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 60 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 61 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 62 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 63 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 64 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 65 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 66 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 67 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 68 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 69 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 70 : NOISE!
# INFO:root:database/Krystian/vsKrystian2 : 71 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 72 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 73 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 74 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 75 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 76 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 77 : NOISE!
# INFO:root:database/Krystian/vsKrystian2 : 78 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 79 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 80 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 81 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 82 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 83 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 84 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 85 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 86 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 87 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 88 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 89 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 90 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 91 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 92 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 93 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 94 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 95 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 96 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 97 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 98 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 99 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 100 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 101 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 102 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 103 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 104 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 105 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 106 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 107 : NOISE!
# INFO:root:database/Krystian/vsKrystian2 : 108 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 109 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 110 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 111 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 112 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 113 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 114 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 115 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 116 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 117 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 118 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 119 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 120 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 121 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 122 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 123 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 124 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 125 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 126 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 127 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 128 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 129 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 130 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 131 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 132 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 133 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 134 : successfully choped
# INFO:root:database/Krystian/vsKrystian2 : 135 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 15 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 16 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 17 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 18 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 19 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 20 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 21 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 22 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 23 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 24 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 25 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 26 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 27 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 28 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 29 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 30 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 31 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 32 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 33 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 34 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 35 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 36 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 37 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 38 : NOISE!
# INFO:root:database/Krystian/vsKrystian3 : 39 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 40 : successfully choped
# INFO:root:database/Krystian/vsKrystian3 : 41 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 15 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 16 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 17 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 18 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 19 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 20 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 21 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 22 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 23 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 24 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 25 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 26 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 27 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 28 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 29 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 30 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 31 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 32 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 33 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 34 : NOISE!
# INFO:root:database/Krystian/vsKrystian4 : 35 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 36 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 37 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 38 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 39 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 40 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 41 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 42 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 43 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 44 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 45 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 46 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 47 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 48 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 49 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 50 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 51 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 52 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 53 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 54 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 55 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 56 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 57 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 58 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 59 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 60 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 61 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 62 : successfully choped
# INFO:root:database/Krystian/vsKrystian4 : 63 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 15 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 16 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 17 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 18 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 19 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 20 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 21 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 22 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 23 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 24 : successfully choped
# INFO:root:database/Krystian/vsKrystian5 : 25 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 15 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 16 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 17 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 18 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 19 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 20 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 21 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 22 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 23 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 24 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 25 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 26 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 27 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 28 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 29 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 30 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 31 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 32 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 33 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 34 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 35 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 36 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 37 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 38 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 39 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 40 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 41 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 42 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 43 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 44 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 45 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 46 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 47 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 48 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 49 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 50 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 51 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 52 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 53 : successfully choped
# INFO:root:database/Krystian/vsKrystian6 : 54 : NOISE!
# INFO:root:database/Krystian/vsKrystian6 : 54 : NOISE!
# INFO:root:database/Krystian/vsKrystian7 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 15 : NOISE!
# INFO:root:database/Krystian/vsKrystian7 : 16 : NOISE!
# INFO:root:database/Krystian/vsKrystian7 : 17 : NOISE!
# INFO:root:database/Krystian/vsKrystian7 : 18 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 19 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 20 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 21 : NOISE!
# INFO:root:database/Krystian/vsKrystian7 : 22 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 23 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 24 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 25 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 26 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 27 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 28 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 29 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 30 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 31 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 32 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 33 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 34 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 35 : NOISE!
# INFO:root:database/Krystian/vsKrystian7 : 36 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 37 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 38 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 39 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 40 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 41 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 42 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 43 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 44 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 45 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 46 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 47 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 48 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 49 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 50 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 51 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 52 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 53 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 54 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 55 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 56 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 57 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 58 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 59 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 60 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 61 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 62 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 63 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 64 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 65 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 66 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 67 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 68 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 69 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 70 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 71 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 72 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 73 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 74 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 75 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 76 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 77 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 78 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 79 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 80 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 81 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 82 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 83 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 84 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 85 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 86 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 87 : NOISE!
# INFO:root:database/Krystian/vsKrystian7 : 88 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 89 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 90 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 91 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 92 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 93 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 94 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 95 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 96 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 97 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 98 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 99 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 100 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 101 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 102 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 103 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 104 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 105 : NOISE!
# INFO:root:database/Krystian/vsKrystian7 : 106 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 107 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 108 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 109 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 110 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 111 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 112 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 113 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 114 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 115 : NOISE!
# INFO:root:database/Krystian/vsKrystian7 : 116 : successfully choped
# INFO:root:database/Krystian/vsKrystian7 : 117 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 15 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 16 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 17 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 18 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 19 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 20 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 21 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 22 : NOISE!
# INFO:root:database/Krystian/vsKrystian8 : 23 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 24 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 25 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 26 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 27 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 28 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 29 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 30 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 31 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 32 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 33 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 34 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 35 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 36 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 37 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 38 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 39 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 40 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 41 : NOISE!
# INFO:root:database/Krystian/vsKrystian8 : 42 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 43 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 44 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 45 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 46 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 47 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 48 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 49 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 50 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 51 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 52 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 53 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 54 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 55 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 56 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 57 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 58 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 59 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 60 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 61 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 62 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 63 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 64 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 65 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 66 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 67 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 68 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 69 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 70 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 71 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 72 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 73 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 74 : successfully choped
# INFO:root:database/Krystian/vsKrystian8 : 75 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 15 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 16 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 17 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 18 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 19 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 20 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 21 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 22 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 23 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 24 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 25 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 26 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 27 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 28 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 29 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 30 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 31 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 32 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 33 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 34 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 35 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 36 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 37 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 38 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 39 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 40 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 41 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 42 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 43 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 44 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 45 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 46 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 47 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 48 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 49 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 50 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 51 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 52 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 53 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 54 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 55 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 56 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 57 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 58 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 59 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 60 : successfully choped
# INFO:root:database/Krystian/vsKrystian9 : 61 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 15 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 16 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 17 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 18 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 19 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 20 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 21 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 22 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 23 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 24 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 25 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 26 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 27 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 28 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 29 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 30 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 31 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 32 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 33 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 34 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 35 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 36 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 37 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 38 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 39 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 40 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 41 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 42 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 43 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 44 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 45 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 46 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 47 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 48 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 49 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 50 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 51 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 52 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 53 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 54 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 55 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 56 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 57 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 58 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 59 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 60 : successfully choped
# INFO:root:database/Krystian/vsKrystian10 : 61 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 1 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 2 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 3 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 4 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 5 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 6 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 7 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 8 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 9 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 10 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 11 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 12 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 13 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 14 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 15 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 16 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 17 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 18 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 19 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 20 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 21 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 22 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 23 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 24 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 25 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 26 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 27 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 28 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 29 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 30 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 31 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 32 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 33 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 34 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 35 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 36 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 37 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 38 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 39 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 40 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 41 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 42 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 43 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 44 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 45 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 46 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 47 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 48 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 49 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 50 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 51 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 52 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 53 : successfully choped
# INFO:root:database/Krystian/vsKrystian11 : 54 : successfully choped
# ...
# INFO:root: database/Nicia/ : ChopedSample 694 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 695 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 696 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 697 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 698 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 699 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 700 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 701 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 702 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 703 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 704 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 705 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 706 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 707 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 708 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 709 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 710 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 711 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 712 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 713 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 714 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 715 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 716 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 717 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 718 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 719 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 720 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 721 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 722 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 723 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 724 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 725 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 726 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 727 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 728 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 729 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 730 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 731 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 732 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 733 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 734 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 735 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 736 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 737 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 738 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 739 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 740 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 741 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 742 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 743 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 744 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 745 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 746 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 747 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 748 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 749 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 750 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 751 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 752 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 753 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 754 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 755 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 756 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 757 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 758 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 759 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 760 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 761 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 762 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 763 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 764 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 765 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 766 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 767 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 768 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 769 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 770 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 771 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 772 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 773 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 774 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 775 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 776 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 777 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 778 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 779 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 780 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 781 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 782 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 783 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 784 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 785 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 786 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 787 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 788 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 789 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 790 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 791 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 792 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 793 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 794 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 795 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 796 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 797 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 798 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 799 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 800 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 801 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 802 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 803 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 804 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 805 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 806 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 807 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 808 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 809 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 810 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 811 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 812 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 813 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 814 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 815 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 816 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 817 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 818 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 819 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 820 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 821 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 822 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 823 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 824 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 825 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 826 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 827 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 828 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 829 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 830 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 831 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 832 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 833 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 834 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 835 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 836 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 837 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 838 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 839 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 840 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 841 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 842 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 843 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 844 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 845 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 846 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 847 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 848 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 849 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 850 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 851 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 852 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 853 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 854 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 855 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 856 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 857 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 858 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 859 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 860 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 861 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 862 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 863 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 864 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 865 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 866 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 867 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 868 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 869 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 870 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 871 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 872 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 873 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 874 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 875 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 876 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 877 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 878 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 879 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 880 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 881 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 882 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 883 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 884 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 885 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 886 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 887 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 888 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 889 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 890 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 891 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 892 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 893 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 894 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 895 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 896 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 897 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 898 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 899 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 900 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 901 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 902 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 903 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 904 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 905 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 906 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 907 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 908 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 909 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 910 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 911 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 912 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 913 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 914 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 915 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 916 :  : converted to tensor
# INFO:root: database/Nicia/ : ChopedSample 917 :  : converted to tensor
# INFO:root:Sucessfully converted all ChopedSamples to Tensors!

# %%
# create net from VoiceRecogModel
net = VoiceRecogModel()

# loss function (using function implemented in pytorch)
criterion = nn.MSELoss()

# create your optimizer (basic optimizer)
# setting learning rate 
optimizer = optim.SGD(net.parameters(), lr=0.4)

# %%
import logging
logging.basicConfig(level=logging.INFO)
trainLog = logging.getLogger()

# Training Loop

# How many times learn on the same dataset
epoch = 2 
for i in range(epoch):   
    for k in range(len(vsInput)):  
        try:
            vs, target = vsInput[k]

            vs_n = (vs+80)/80

            optimizer.zero_grad()   # zero the gradient buffers
            input = vs_n.view(-1,1,256,256)
            output = net(input)

            loss = criterion(output, target)

            loss.backward()
            optimizer.step()    # Does the update


            info = "Training " + str(k)+"/"+str(len(vsInput))+" done"

            print("\n")
            print(target)
            print(output)
            print(loss)
            print(info)
        except Exception as e:
            print(e)
            pass
# Out:
# tensor([[1., 0.]])
# tensor([[0.0189, 0.0242]], grad_fn=<AddmmBackward>)
# tensor(0.4816, grad_fn=<MseLossBackward>)
# Training 0/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[2.7201, 0.3455]], grad_fn=<AddmmBackward>)
# tensor(3.9137, grad_fn=<MseLossBackward>)
# Training 1/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[-1.5263,  0.4670]], grad_fn=<AddmmBackward>)
# tensor(3.3002, grad_fn=<MseLossBackward>)
# Training 2/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.3429, 0.0721]], grad_fn=<AddmmBackward>)
# tensor(0.4893, grad_fn=<MseLossBackward>)
# Training 3/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.1108, 0.4796]], grad_fn=<AddmmBackward>)
# tensor(0.5103, grad_fn=<MseLossBackward>)
# Training 4/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.5764, 0.2628]], grad_fn=<AddmmBackward>)
# tensor(0.4378, grad_fn=<MseLossBackward>)
# Training 5/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3413, 0.5652]], grad_fn=<AddmmBackward>)
# tensor(0.3767, grad_fn=<MseLossBackward>)
# Training 6/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6082, 0.3342]], grad_fn=<AddmmBackward>)
# tensor(0.4066, grad_fn=<MseLossBackward>)
# Training 7/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3608, 0.6055]], grad_fn=<AddmmBackward>)
# tensor(0.3876, grad_fn=<MseLossBackward>)
# Training 8/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6188, 0.3587]], grad_fn=<AddmmBackward>)
# tensor(0.3971, grad_fn=<MseLossBackward>)
# Training 9/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3680, 0.6187]], grad_fn=<AddmmBackward>)
# tensor(0.3911, grad_fn=<MseLossBackward>)
# Training 10/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6222, 0.3674]], grad_fn=<AddmmBackward>)
# tensor(0.3937, grad_fn=<MseLossBackward>)
# Training 11/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3708, 0.6229]], grad_fn=<AddmmBackward>)
# tensor(0.3920, grad_fn=<MseLossBackward>)
# Training 12/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6233, 0.3707]], grad_fn=<AddmmBackward>)
# tensor(0.3923, grad_fn=<MseLossBackward>)
# Training 13/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3721, 0.6242]], grad_fn=<AddmmBackward>)
# tensor(0.3919, grad_fn=<MseLossBackward>)
# Training 14/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6238, 0.3721]], grad_fn=<AddmmBackward>)
# tensor(0.3917, grad_fn=<MseLossBackward>)
# Training 15/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3729, 0.6246]], grad_fn=<AddmmBackward>)
# tensor(0.3917, grad_fn=<MseLossBackward>)
# Training 16/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6239, 0.3728]], grad_fn=<AddmmBackward>)
# tensor(0.3913, grad_fn=<MseLossBackward>)
# Training 17/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3733, 0.6247]], grad_fn=<AddmmBackward>)
# tensor(0.3915, grad_fn=<MseLossBackward>)
# Training 18/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6241, 0.3733]], grad_fn=<AddmmBackward>)
# tensor(0.3911, grad_fn=<MseLossBackward>)
# Training 19/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3737, 0.6247]], grad_fn=<AddmmBackward>)
# tensor(0.3912, grad_fn=<MseLossBackward>)
# Training 20/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6242, 0.3736]], grad_fn=<AddmmBackward>)
# tensor(0.3910, grad_fn=<MseLossBackward>)
# Training 21/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3739, 0.6247]], grad_fn=<AddmmBackward>)
# tensor(0.3911, grad_fn=<MseLossBackward>)
# Training 22/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6243, 0.3738]], grad_fn=<AddmmBackward>)
# tensor(0.3909, grad_fn=<MseLossBackward>)
# Training 23/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3741, 0.6247]], grad_fn=<AddmmBackward>)
# tensor(0.3910, grad_fn=<MseLossBackward>)
# Training 24/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6243, 0.3740]], grad_fn=<AddmmBackward>)
# tensor(0.3908, grad_fn=<MseLossBackward>)
# Training 25/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3743, 0.6247]], grad_fn=<AddmmBackward>)
# tensor(0.3909, grad_fn=<MseLossBackward>)
# Training 26/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6244, 0.3742]], grad_fn=<AddmmBackward>)
# tensor(0.3908, grad_fn=<MseLossBackward>)
# Training 27/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3744, 0.6247]], grad_fn=<AddmmBackward>)
# tensor(0.3908, grad_fn=<MseLossBackward>)
# Training 28/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6245, 0.3743]], grad_fn=<AddmmBackward>)
# tensor(0.3907, grad_fn=<MseLossBackward>)
# Training 29/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3745, 0.6247]], grad_fn=<AddmmBackward>)
# tensor(0.3908, grad_fn=<MseLossBackward>)
# Training 30/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6245, 0.3744]], grad_fn=<AddmmBackward>)
# tensor(0.3907, grad_fn=<MseLossBackward>)
# Training 31/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3746, 0.6247]], grad_fn=<AddmmBackward>)
# tensor(0.3907, grad_fn=<MseLossBackward>)
# Training 32/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6246, 0.3745]], grad_fn=<AddmmBackward>)
# tensor(0.3907, grad_fn=<MseLossBackward>)
# Training 33/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3747, 0.6248]], grad_fn=<AddmmBackward>)
# tensor(0.3907, grad_fn=<MseLossBackward>)
# Training 34/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6247, 0.3746]], grad_fn=<AddmmBackward>)
# tensor(0.3907, grad_fn=<MseLossBackward>)
# Training 35/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3747, 0.6248]], grad_fn=<AddmmBackward>)
# tensor(0.3907, grad_fn=<MseLossBackward>)
# Training 36/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6247, 0.3746]], grad_fn=<AddmmBackward>)
# tensor(0.3907, grad_fn=<MseLossBackward>)
# Training 37/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3748, 0.6248]], grad_fn=<AddmmBackward>)
# tensor(0.3907, grad_fn=<MseLossBackward>)
# Training 38/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6247, 0.3747]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 39/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3748, 0.6248]], grad_fn=<AddmmBackward>)
# tensor(0.3907, grad_fn=<MseLossBackward>)
# Training 40/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6248, 0.3747]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 41/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3748, 0.6249]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 42/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6248, 0.3748]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 43/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3749, 0.6249]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 44/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6248, 0.3748]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 45/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3749, 0.6249]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 46/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6249, 0.3748]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 47/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3749, 0.6249]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 48/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6249, 0.3749]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 49/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3749, 0.6249]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 50/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6249, 0.3749]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 51/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3749, 0.6249]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 52/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6249, 0.3749]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 53/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3749, 0.6249]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 54/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6249, 0.3749]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 55/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3749, 0.6249]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 56/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6249, 0.3749]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 57/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 58/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6249, 0.3749]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 59/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 60/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6249, 0.3749]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 61/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 62/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 63/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 64/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 65/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 66/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 67/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 68/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 69/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 70/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 71/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 72/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 73/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 74/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 75/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 76/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 77/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 78/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 79/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 80/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 81/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 82/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 83/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 84/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 85/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 86/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 87/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 88/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 89/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 90/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 91/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 92/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 93/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 94/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 95/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 96/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 97/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 98/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 99/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 100/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 101/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 102/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 103/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 104/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 105/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 106/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 107/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 108/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 109/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 110/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 111/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 112/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 113/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 114/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 115/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 116/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 117/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 118/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 119/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 120/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 121/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 122/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 123/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 124/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 125/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 126/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 127/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 128/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 129/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 130/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 131/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 132/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 133/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 134/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 135/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 136/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 137/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 138/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 139/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 140/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 141/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 142/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 143/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 144/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 145/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 146/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 147/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 148/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 149/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 150/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 151/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 152/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 153/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 154/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 155/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 156/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 157/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 158/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 159/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 160/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 161/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 162/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 163/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 164/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 165/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 166/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 167/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 168/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 169/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 170/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 171/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 172/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 173/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 174/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 175/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 176/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 177/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 178/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 179/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 180/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 181/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 182/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 183/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 184/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 185/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 186/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 187/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 188/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 189/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 190/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 191/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 192/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 193/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 194/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 195/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 196/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 197/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 198/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 199/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 200/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 201/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 202/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 203/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 204/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 205/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 206/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 207/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 208/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 209/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 210/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 211/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 212/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 213/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 214/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 215/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 216/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 217/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 218/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 219/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 220/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 221/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 222/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 223/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 224/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 225/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 226/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 227/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 228/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 229/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 230/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 231/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 232/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 233/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 234/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 235/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 236/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 237/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 238/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 239/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 240/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 241/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 242/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 243/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 244/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 245/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 246/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 247/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 248/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 249/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 250/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 251/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 252/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 253/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 254/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 255/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 256/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 257/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 258/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 259/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 260/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 261/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 262/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 263/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 264/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 265/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 266/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 267/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 268/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 269/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 270/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 271/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 272/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 273/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 274/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 275/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 276/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 277/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 278/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 279/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 280/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 281/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 282/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 283/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 284/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 285/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 286/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 287/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 288/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 289/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 290/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 291/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 292/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 293/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 294/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 295/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 296/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 297/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 298/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 299/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 300/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 301/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 302/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 303/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 304/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 305/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 306/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 307/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 308/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 309/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 310/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 311/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 312/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 313/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 314/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 315/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 316/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 317/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 318/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 319/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 320/1412 done
#
#
# tensor([[0., 1.]])
# tensor([[0.6250, 0.3750]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 321/1412 done
#
#
# tensor([[1., 0.]])
# tensor([[0.3750, 0.6250]], grad_fn=<AddmmBackward>)
# tensor(0.3906, grad_fn=<MseLossBackward>)
# Training 322/1412 done
